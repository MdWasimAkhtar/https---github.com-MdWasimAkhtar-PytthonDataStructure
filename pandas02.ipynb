# %%
import pandas as pd

# %%
data=pd.read_csv('/home/ubuntu-wasim/Documents/machineLearningMatrial/CarPrice_Prediction.csv')
data.head()
# Out:
#     9  1            audi 4000  gas  turbo  four      sedan  fwd  front  105.8  \
# 0  10  0  audi 5000s (diesel)  gas  turbo   two  hatchback  4wd  front   99.5
# 1  11  2             bmw 320i  gas    std   two      sedan  rwd  front  101.2
# 2  12  0             bmw 320i  gas    std  four      sedan  rwd  front  101.2
# 3  13  0               bmw x1  gas    std   two      sedan  rwd  front  101.2
# 4  14  0               bmw x3  gas    std  four      sedan  rwd  front  101.2
#
#    ...  131  mpfi  3.13   3.4  8.3    140    5500  17  20    23875
# 0  ...  131  mpfi  3.13  3.40  7.0  160.0  5500.0  16  22      NaN
# 1  ...  108  mpfi  3.50  2.80  8.8  101.0  5800.0  23  29  16430.0
# 2  ...  108  mpfi  3.50  2.80  8.8  101.0  5800.0  23  29  16925.0
# 3  ...  164  mpfi   NaN  3.19  9.0  121.0  4250.0  21  28  20970.0
# 4  ...  164  mpfi  3.31  3.19  9.0  121.0  4250.0  21  28  21105.0
#
# [5 rows x 26 columns]

# %%
import os
print(os.getcwd())
# Out:
# /home/ubuntu-wasim/Documents/MachinelearningCode

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.columns
# Out:
# Index(['9', '1', 'audi 4000', 'gas', 'turbo', 'four', 'sedan', 'fwd', 'front',
#        '105.8', '192.7', '71.4', '55.9', '3086', 'ohc', 'five', '131', 'mpfi',
#        '3.13', '3.4', '8.3', '140', '5500', '17', '20', '23875'],
#       dtype='object')

# %%
data.keys()
# Out:
# Index(['9', '1', 'audi 4000', 'gas', 'turbo', 'four', 'sedan', 'fwd', 'front',
#        '105.8', '192.7', '71.4', '55.9', '3086', 'ohc', 'five', '131', 'mpfi',
#        '3.13', '3.4', '8.3', '140', '5500', '17', '20', '23875'],
#       dtype='object')

# %%
pd.read_csv('/home/ubuntu-wasim/Documents/machineLearningMatrial/CarPrice_Prediction.csv' , nrows=2)
# Out:
#     9  1            audi 4000  gas  turbo four      sedan  fwd  front  105.8  \
# 0  10  0  audi 5000s (diesel)  gas  turbo  two  hatchback  4wd  front   99.5
# 1  11  2             bmw 320i  gas    std  two      sedan  rwd  front  101.2
#
#    ...  131  mpfi  3.13  3.4  8.3  140  5500  17  20    23875
# 0  ...  131  mpfi  3.13  3.4  7.0  160  5500  16  22      NaN
# 1  ...  108  mpfi  3.50  2.8  8.8  101  5800  23  29  16430.0
#
# [2 rows x 26 columns]

# %%
pd.read_csv('/home/ubuntu-wasim/Documents/machineLearningMatrial/CarPrice_Prediction.csv',usecols=[0,3])
# Out:
#        9     gas
# 0     10     gas
# 1     11     gas
# 2     12     gas
# 3     13     gas
# 4     14     gas
# ..   ...     ...
# 191  201     gas
# 192  202     gas
# 193  203     gas
# 194  204  diesel
# 195  205     gas
#
# [196 rows x 2 columns]

# %%
pd.read_csv('/home/ubuntu-wasim/Documents/machineLearningMatrial/CarPrice_Prediction.csv',skiprows=[0])
# Out:
#       10  0 audi 5000s (diesel)     gas  turbo   two hatchback  4wd  front  \
# 0     11  2            bmw 320i     gas    std   two     sedan  rwd  front
# 1     12  0            bmw 320i     gas    std  four     sedan  rwd  front
# 2     13  0              bmw x1     gas    std   two     sedan  rwd  front
# 3     14  0              bmw x3     gas    std  four     sedan  rwd  front
# 4     15  1              bmw z4     gas    std  four     sedan  rwd  front
# ..   ... ..                 ...     ...    ...   ...       ...  ...    ...
# 190  201 -1     volvo 145e (sw)     gas    std  four     sedan  rwd  front
# 191  202 -1         volvo 144ea     gas  turbo  four     sedan  rwd  front
# 192  203 -1         volvo 244dl     gas    std  four     sedan  rwd  front
# 193  204 -1           volvo 246  diesel  turbo  four     sedan  rwd  front
# 194  205 -1         volvo 264gl     gas  turbo  four     sedan  rwd  front
#
# ...

# %% [markdown]
# #header

# %% [markdown]
# change dtype

# %%
pd.read_csv('/home/ubuntu-wasim/Documents/machineLearningMatrial/CarPrice_Prediction.csv',dtype={'car_ID': 'float32'})
# Out:
#        9  1            audi 4000     gas  turbo  four      sedan  fwd  front  \
# 0     10  0  audi 5000s (diesel)     gas  turbo   two  hatchback  4wd  front
# 1     11  2             bmw 320i     gas    std   two      sedan  rwd  front
# 2     12  0             bmw 320i     gas    std  four      sedan  rwd  front
# 3     13  0               bmw x1     gas    std   two      sedan  rwd  front
# 4     14  0               bmw x3     gas    std  four      sedan  rwd  front
# ..   ... ..                  ...     ...    ...   ...        ...  ...    ...
# 191  201 -1      volvo 145e (sw)     gas    std  four      sedan  rwd  front
# 192  202 -1          volvo 144ea     gas  turbo  four      sedan  rwd  front
# 193  203 -1          volvo 244dl     gas    std  four      sedan  rwd  front
# 194  204 -1            volvo 246  diesel  turbo  four      sedan  rwd  front
# 195  205 -1          volvo 264gl     gas  turbo  four      sedan  rwd  front
#
# ...

# %% [markdown]
# true_false=['yes']
# false_value=['No']

# %% [markdown]
# Handling missing value in python

# %%
df = pd.read_csv('/home/ubuntu-wasim/Documents/machineLearningMatrial/CarPrice_Prediction.csv')
df.head()
# Out:
#     9  1            audi 4000  gas  turbo  four      sedan  fwd  front  105.8  \
# 0  10  0  audi 5000s (diesel)  gas  turbo   two  hatchback  4wd  front   99.5
# 1  11  2             bmw 320i  gas    std   two      sedan  rwd  front  101.2
# 2  12  0             bmw 320i  gas    std  four      sedan  rwd  front  101.2
# 3  13  0               bmw x1  gas    std   two      sedan  rwd  front  101.2
# 4  14  0               bmw x3  gas    std  four      sedan  rwd  front  101.2
#
#    ...  131  mpfi  3.13   3.4  8.3    140    5500  17  20    23875
# 0  ...  131  mpfi  3.13  3.40  7.0  160.0  5500.0  16  22      NaN
# 1  ...  108  mpfi  3.50  2.80  8.8  101.0  5800.0  23  29  16430.0
# 2  ...  108  mpfi  3.50  2.80  8.8  101.0  5800.0  23  29  16925.0
# 3  ...  164  mpfi   NaN  3.19  9.0  121.0  4250.0  21  28  20970.0
# 4  ...  164  mpfi  3.31  3.19  9.0  121.0  4250.0  21  28  21105.0
#
# [5 rows x 26 columns]

# %%
df.isnull().sum().sum()
# Out:
# 19

# %%
df.isnull().sum()
# Out:
# 9            0
# 1            0
# audi 4000    0
# gas          0
# turbo        0
# four         0
# sedan        0
# fwd          0
# front        0
# 105.8        1
# 192.7        1
# 71.4         0
# 55.9         2
# 3086         4
# ohc          0
# five         0
# 131          0
# mpfi         0
# 3.13         4
# 3.4          0
# 8.3          0
# 140          1
# 5500         2
# 17           0
# 20           0
# 23875        4
# dtype: int64
